# %%
# %matplotlib nbagg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
primary = pd.read_csv('data/2016-presidential-election/primary_results.csv', sep=',')

# %%
countries = pd.read_csv('data/2016-presidential-election/county_facts.csv', sep=',')

# %%
primary.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
countries.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# 0       28.8  5319456312  4174286516  3917663456      12990  613795732
# 1       28.1   112858843    52252752    57344851      12364    6426342
# 2       31.7           0           0      598175      12003      88157
# 3       27.3     1410273           0     2966489      17166     436955
# 4       27.0           0           0      188337       6334          0
#
#    BPS030214   LND110210  POP060210
# 0    1046363  3531905.43       87.4
# 1      13369    50645.33       94.4
# 2        131      594.44       91.8
# 3       1384     1589.78      114.6
# 4          8      884.88       31.0
#
# [5 rows x 54 columns]

# %%
primary.columns
# Out:
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='object')

# %%
primary.shape
# Out:
# (24611, 8)

# %%
countries.columns
# Out:
# Index(['fips', 'area_name', 'state_abbreviation', 'PST045214', 'PST040210',
#        'PST120214', 'POP010210', 'AGE135214', 'AGE295214', 'AGE775214',
#        'SEX255214', 'RHI125214', 'RHI225214', 'RHI325214', 'RHI425214',
#        'RHI525214', 'RHI625214', 'RHI725214', 'RHI825214', 'POP715213',
#        'POP645213', 'POP815213', 'EDU635213', 'EDU685213', 'VET605213',
#        'LFE305213', 'HSG010214', 'HSG445213', 'HSG096213', 'HSG495213',
#        'HSD410213', 'HSD310213', 'INC910213', 'INC110213', 'PVY020213',
#        'BZA010213', 'BZA110213', 'BZA115213', 'NES010213', 'SBO001207',
#        'SBO315207', 'SBO115207', 'SBO215207', 'SBO515207', 'SBO415207',
#        'SBO015207', 'MAN450207', 'WTN220207', 'RTN130207', 'RTN131207',
#        'AFN120207', 'BPS030214', 'LND110210', 'POP060210'],
#       dtype='object')

# %%
countries.shape
# Out:
# (3195, 54)

# %%
primary.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
 primary['candidate'].unique()
# Out:
# array(['Bernie Sanders', 'Hillary Clinton', 'Ben Carson', 'Donald Trump',
#        'John Kasich', 'Marco Rubio', 'Ted Cruz', ' Uncommitted',
#        "Martin O'Malley", 'Carly Fiorina', 'Chris Christie', 'Jeb Bush',
#        'Mike Huckabee', 'Rand Paul', 'Rick Santorum', ' No Preference'], dtype=object)

# %%
primary.groupby('candidate')['votes'].sum()
# Out:
# candidate
#  No Preference         8152
#  Uncommitted             43
# Ben Carson           564553
# Bernie Sanders     11959102
# Carly Fiorina         15191
# Chris Christie        24353
# Donald Trump       13302541
# Hillary Clinton    15692452
# Jeb Bush              94411
# John Kasich         4159949
# Marco Rubio         3321076
# Martin O'Malley         752
# Mike Huckabee          3345
# Rand Paul              8479
# Rick Santorum          1782
# Ted Cruz            7603006
# Name: votes, dtype: int64

# %%
candidate_to_votes_s = primary.groupby('candidate')['votes'].sum().sort_values()

# %%
candidate_to_votes_s
# Out:
# candidate
#  Uncommitted             43
# Martin O'Malley         752
# Rick Santorum          1782
# Mike Huckabee          3345
#  No Preference         8152
# Rand Paul              8479
# Carly Fiorina         15191
# Chris Christie        24353
# Jeb Bush              94411
# Ben Carson           564553
# Marco Rubio         3321076
# John Kasich         4159949
# Ted Cruz            7603006
# Bernie Sanders     11959102
# Donald Trump       13302541
# Hillary Clinton    15692452
# Name: votes, dtype: int64

# %%
candidate_to_votes_s.plot(kind='barh', fontsize=8)
# Out:
# <img src="data:image/png;base64,..." width="746">

# %%
primary.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
state_party_to_votes_s = primary.groupby(['state', 'party'])['votes'].sum()

# %%
state_party_to_votes_s.head()
# Out:
# state    party
# Alabama  Democrat      386327
#          Republican    837632
# Alaska   Democrat         539
#          Republican     21930
# Arizona  Democrat      399097
# Name: votes, dtype: int64

# %%
state_to_votes_s = primary.groupby('state')['votes'].sum()

# %%
state_to_votes_s.head()
# Out:
# state
# Alabama       1223959
# Alaska          22469
# Arizona        834200
# Arkansas       605971
# California    4938197
# Name: votes, dtype: int64

# %%
state_party_to_votes_pcts_s = state_party_to_votes_s / state_to_votes_s

# %%
state_party_to_votes_pcts_s.head()
# Out:
# state    party
# Alabama  Democrat      0.315637
#          Republican    0.684363
# Alaska   Democrat      0.023989
#          Republican    0.976011
# Arizona  Democrat      0.478419
# Name: votes, dtype: float64

# %%
state_party_to_votes_pcts_s.unstack().plot(kind='barh', stacked=True, fontsize=8)
# Out:
# <img src="data:image/png;base64,..." width="925">

# %%
func = lambda agg_df: agg_df.sort_values('votes', ascending=False).iloc[0]

# %%
primary.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
winners = primary.groupby('fips').agg(func)

# %%
winners.head()
# Out:
#           state state_abbreviation   county       party        candidate  \
# fips
# 1001.0  Alabama                 AL  Autauga  Republican     Donald Trump
# 1003.0  Alabama                 AL  Baldwin  Republican     Donald Trump
# 1005.0  Alabama                 AL  Barbour    Democrat  Hillary Clinton
# 1007.0  Alabama                 AL     Bibb  Republican     Donald Trump
# 1009.0  Alabama                 AL   Blount  Republican     Donald Trump
#
#         votes  fraction_votes
# fips
# 1001.0   5387           0.445
# 1003.0  23618           0.469
# 1005.0   2567           0.906
# 1007.0   1959           0.494
# 1009.0   7390           0.487

# %%
countries.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# 0       28.8  5319456312  4174286516  3917663456      12990  613795732
# 1       28.1   112858843    52252752    57344851      12364    6426342
# 2       31.7           0           0      598175      12003      88157
# 3       27.3     1410273           0     2966489      17166     436955
# 4       27.0           0           0      188337       6334          0
#
#    BPS030214   LND110210  POP060210
# 0    1046363  3531905.43       87.4
# 1      13369    50645.33       94.4
# 2        131      594.44       91.8
# 3       1384     1589.78      114.6
# 4          8      884.88       31.0
#
# [5 rows x 54 columns]

# %%
countries.columns
# Out:
# Index(['fips', 'area_name', 'state_abbreviation', 'PST045214', 'PST040210',
#        'PST120214', 'POP010210', 'AGE135214', 'AGE295214', 'AGE775214',
#        'SEX255214', 'RHI125214', 'RHI225214', 'RHI325214', 'RHI425214',
#        'RHI525214', 'RHI625214', 'RHI725214', 'RHI825214', 'POP715213',
#        'POP645213', 'POP815213', 'EDU635213', 'EDU685213', 'VET605213',
#        'LFE305213', 'HSG010214', 'HSG445213', 'HSG096213', 'HSG495213',
#        'HSD410213', 'HSD310213', 'INC910213', 'INC110213', 'PVY020213',
#        'BZA010213', 'BZA110213', 'BZA115213', 'NES010213', 'SBO001207',
#        'SBO315207', 'SBO115207', 'SBO215207', 'SBO515207', 'SBO415207',
#        'SBO015207', 'MAN450207', 'WTN220207', 'RTN130207', 'RTN131207',
#        'AFN120207', 'BPS030214', 'LND110210', 'POP060210'],
#       dtype='object')

# %%
countries['RHI825214'].head()
# Out:
# 0    62.1
# 1    66.2
# 2    75.6
# 3    83.0
# 4    46.6
# Name: RHI825214, dtype: float64

# %%
countries[['fips', 'RHI825214']].head()
# Out:
#    fips  RHI825214
# 0     0       62.1
# 1  1000       66.2
# 2  1001       75.6
# 3  1003       83.0
# 4  1005       46.6

# %%
winners.head()
# Out:
#           state state_abbreviation   county       party        candidate  \
# fips
# 1001.0  Alabama                 AL  Autauga  Republican     Donald Trump
# 1003.0  Alabama                 AL  Baldwin  Republican     Donald Trump
# 1005.0  Alabama                 AL  Barbour    Democrat  Hillary Clinton
# 1007.0  Alabama                 AL     Bibb  Republican     Donald Trump
# 1009.0  Alabama                 AL   Blount  Republican     Donald Trump
#
#         votes  fraction_votes
# fips
# 1001.0   5387           0.445
# 1003.0  23618           0.469
# 1005.0   2567           0.906
# 1007.0   1959           0.494
# 1009.0   7390           0.487

# %%
winnsers_county_races = pd.merge(winners, countries[['fips', 'RHI825214']],
                                 left_index=True, right_on='fips', how='left')

# %%
winnsers_county_races.head()
# Out:
#      state state_abbreviation   county       party        candidate  votes  \
# 2  Alabama                 AL  Autauga  Republican     Donald Trump   5387
# 3  Alabama                 AL  Baldwin  Republican     Donald Trump  23618
# 4  Alabama                 AL  Barbour    Democrat  Hillary Clinton   2567
# 5  Alabama                 AL     Bibb  Republican     Donald Trump   1959
# 6  Alabama                 AL   Blount  Republican     Donald Trump   7390
#
#    fraction_votes    fips  RHI825214
# 2           0.445  1001.0       75.6
# 3           0.469  1003.0       83.0
# 4           0.906  1005.0       46.6
# 5           0.494  1007.0       74.5
# 6           0.487  1009.0       87.8

# %%
winnsers_county_races = winnsers_county_races.rename(columns={'RHI825214': 'white_pcts'})

# %%
winnsers_county_races.head()
# Out:
#      state state_abbreviation   county       party        candidate  votes  \
# 2  Alabama                 AL  Autauga  Republican     Donald Trump   5387
# 3  Alabama                 AL  Baldwin  Republican     Donald Trump  23618
# 4  Alabama                 AL  Barbour    Democrat  Hillary Clinton   2567
# 5  Alabama                 AL     Bibb  Republican     Donald Trump   1959
# 6  Alabama                 AL   Blount  Republican     Donald Trump   7390
#
#    fraction_votes    fips  white_pcts
# 2           0.445  1001.0        75.6
# 3           0.469  1003.0        83.0
# 4           0.906  1005.0        46.6
# 5           0.494  1007.0        74.5
# 6           0.487  1009.0        87.8

# %%
winners_county_white_pcts = winnsers_county_races.groupby(['party', 'candidate'])['white_pcts'].mean()

# %%
winners_county_white_pcts.head()
# Out:
# party       candidate
# Democrat     No Preference           NaN
#             Bernie Sanders     81.220541
#             Hillary Clinton    54.609481
# Republican  Donald Trump       84.008129
#             John Kasich        89.226415
# Name: white_pcts, dtype: float64

# %%
ax = winners_county_white_pcts.plot(kind='barh', fontsize=8)
# Out:
# <img src="data:image/png;base64,..." width="639.8999694871917">

# %%
ax.set_xlim([50, 100])
plt.tight_layout()

# %%
# pivot table

# %%
total_votes = primary.pivot_table(values='votes', index='state', columns='candidate', aggfunc='sum', fill_value=0)

# %%
total_votes
# Out:
# candidate        No Preference   Uncommitted  Ben Carson  Bernie Sanders  \
# state
# Alabama                      0             0       87517           76399
# Alaska                       0             0        2401             440
# Arizona                      0             0           0          163400
# Arkansas                     0             0       23173           64868
# California                   0             0           0         1502043
# Colorado                     0             0           0           71928
# Connecticut                  0             0           0          152410
# Delaware                     0             0           0           36659
# Florida                      0             0           0          566603
# Georgia                      0             0       80503          214332
# Hawaii                       0             0           0           23531
# Idaho                        0             0           0           18640
# Illinois                     0             0           0          975659
# Indiana                      0             0           0          335256
# Iowa                         0            43       17393           69452
# Kansas                       0             0           0           26450
# Kentucky                     0             0           0          210626
# Louisiana                    0             0           0           72240
# Maine                        0             0           0            2201
# Maryland                     0             0           0          281275
# Massachusetts             8152             0       16277          586716
# Michigan                     0             0           0          595222
# Mississippi                  0             0           0           36348
# Missouri                     0             0           0          309071
# Montana                      0             0           0           63168
# Nebraska                     0             0           0           19120
# Nevada                       0             0        3619            5641
# New Hampshire                0             0        6509          151584
# New Jersey                   0             0           0          323259
# New Mexico                   0             0           0          103856
# New York                     0             0           0          763469
# North Carolina               0             0           0          460316
# North Dakota                 0             0           0             253
# Ohio                         0             0           0          513549
# Oklahoma                     0             0       28572          174054
# Oregon                       0             0           0          320746
# Pennsylvania                 0             0           0          719955
# Rhode Island                 0             0           0           66720
# South Carolina               0             0       53326           95977
# South Dakota                 0             0           0           25958
# Tennessee                    0             0       64846          120333
# Texas                        0             0      117780          475561
# Utah                         0             0           0           61333
# Vermont                      0             0        2544          115863
# Virginia                     0             0       60093          275507
# Washington                   0             0           0           19159
# West Virginia                0             0           0          123860
# Wisconsin                    0             0           0          567936
# Wyoming                      0             0           0             156
#
# candidate       Carly Fiorina  Chris Christie  Donald Trump  Hillary Clinton  \
# state
# Alabama                     0               0        371735           309928
# Alaska                      0               0          7346               99
# Arizona                     0               0        249916           235697
# Arkansas                    0               0        133144           144580
# California                  0               0       1174829          1940580
# Colorado                    0               0             0            49256
# Connecticut                 0               0        123367           170075
# Delaware                    0               0         42472            55950
# Florida                     0               0       1077221          1097400
# Georgia                     0               0        501707           543008
# Hawaii                      0               0          5677            10127
# Idaho                       0               0         62478             5065
# Illinois                    0               0        551464          1012175
# Indiana                     0               0        590460           303382
# Iowa                     3485            3284         45419            69733
# Kansas                      0               0         17062            12593
# Kentucky                    0               0         82493           212550
# Louisiana                   0               0        124818           221615
# Maine                       0               0             0             1214
# Maryland                    0               0        236623           533247
# Massachusetts               0               0        311313           603784
# Michigan                    0               0        483751           576795
# Mississippi                 0               0        191755           182447
# Missouri                    0               0        382093           310602
# Montana                     0               0        114056            55194
# Nebraska                    0               0        121287            14340
# Nevada                      0               0         34531             6296
# New Hampshire           11706           21069        100406            95252
# New Jersey                  0               0        356697           554237
# New Mexico                  0               0         73530           110451
# New York                    0               0        524932          1054083
# North Carolina              0               0        458151           616383
# North Dakota                0               0             0              101
# Ohio                        0               0        727585           679266
# Oklahoma                    0               0        130141           139338
# Oregon                      0               0        240804           251739
# Pennsylvania                0               0        892702           918689
# Rhode Island                0               0         39059            52493
# South Carolina              0               0        239851           271514
# South Dakota                0               0         44866            27046
# Tennessee                   0               0        332702           245304
# Texas                       0               0        757618           935080
# Utah                        0               0         24864            15666
# Vermont                     0               0         19968            18335
# Virginia                    0               0        355960           503358
# Washington                  0               0        403003             7140
# West Virginia               0               0        156245            86354
# Wisconsin                   0               0        386370           432767
# Wyoming                     0               0            70              124
#
# candidate       Jeb Bush  John Kasich  Marco Rubio  Martin O'Malley  \
# state
# Alabama                0        37970       159802                0
# Alaska                 0          892         3318                0
# Arizona                0        53040            0                0
# Arkansas               0        15098       101235                0
# California             0       176620            0                0
# Colorado               0            0            0                0
# Connecticut            0        60481            0                0
# Delaware               0        14225            0                0
# Florida                0       159412       636653                0
# Georgia                0        72303       315979                0
# Hawaii                 0         1413         1759                0
# Idaho                  0        16517        35347                0
# Illinois               0       279778       123066                0
# Indiana                0        83913            0                0
# Iowa                5238         3472        43164              752
# Kansas                 0         7795        12189                0
# Kentucky               0        33134        37579                0
# Louisiana              0        19355        33804                0
# Maine                  0            0            0                0
# Maryland               0       100089            0                0
# Massachusetts          0       113783       112822                0
# Michigan               0       321655       123673                0
# Mississippi            0        35817        20768                0
# Missouri               0        92533        57006                0
# Montana                0        10622            0                0
# Nebraska               0        22526            0                0
# Nevada                 0         2709        17940                0
# New Hampshire      31310        44909        30032                0
# New Jersey             0        59506            0                0
# New Mexico             0         7870            0                0
# New York               0       217904            0                0
# North Carolina         0       144299        87858                0
# North Dakota           0            0            0                0
# Ohio                   0       956762        59418                0
# Oklahoma               0        16515       119562                0
# Oregon                 0        59096            0                0
# Pennsylvania           0       304793            0                0
# Rhode Island           0        14929            0                0
# South Carolina     57863        56206       165881                0
# South Dakota           0        10659            0                0
# Tennessee              0        45243       180989                0
# Texas                  0       120257       502223                0
# Utah                   0        29773            0                0
# Vermont                0        18543        11778                0
# Virginia               0        96519       327042                0
# Washington             0        52129            0                0
# West Virginia          0        13685            0                0
# Wisconsin              0       155200            0                0
# Wyoming                0            0          189                0
#
# candidate       Mike Huckabee  Rand Paul  Rick Santorum  Ted Cruz
# state
# Alabama                     0          0              0    180608
# Alaska                      0          0              0      7973
# Arizona                     0          0              0    132147
# Arkansas                    0          0              0    123873
# California                  0          0              0    144125
# Colorado                    0          0              0         0
# Connecticut                 0          0              0     24969
# Delaware                    0          0              0     11110
# Florida                     0          0              0    403640
# Georgia                     0          0              0    305109
# Hawaii                      0          0              0      4379
# Idaho                       0          0              0    100942
# Illinois                    0          0              0    430395
# Indiana                     0          0              0    406280
# Iowa                     3345       8479           1782     51663
# Kansas                      0          0              0     35207
# Kentucky                    0          0              0     72503
# Louisiana                   0          0              0    113949
# Maine                       0          0              0         0
# Maryland                    0          0              0     82038
# Massachusetts               0          0              0     60473
# Michigan                    0          0              0    330015
# Mississippi                 0          0              0    147065
# Missouri                    0          0              0    380367
# Montana                     0          0              0     14476
# Nebraska                    0          0              0     36418
# Nevada                      0          0              0     16079
# New Hampshire               0          0              0     33189
# New Jersey                  0          0              0     27521
# New Mexico                  0          0              0     13825
# New York                    0          0              0    126151
# North Carolina              0          0              0    418740
# North Dakota                0          0              0         0
# Ohio                        0          0              0    267592
# Oklahoma                    0          0              0    157941
# Oregon                      0          0              0     61590
# Pennsylvania                0          0              0    340201
# Rhode Island                0          0              0      6393
# South Carolina              0          0              0    164790
# South Dakota                0          0              0     11352
# Tennessee                   0          0              0    211159
# Texas                       0          0              0   1239370
# Utah                        0          0              0    122567
# Vermont                     0          0              0      5929
# Virginia                    0          0              0    173193
# Washington                  0          0              0     55719
# West Virginia               0          0              0     18208
# Wisconsin                   0          0              0    531129
# Wyoming                     0          0              0       644

# %%
primary.pivot_table(values='fraction_votes', index='state_abbreviation', columns='party', aggfunc='mean')
# Out:
# party               Democrat  Republican
# state_abbreviation
# AK                  0.500000    0.200020
# AL                  0.477000    0.195310
# AR                  0.464973    0.191971
# AZ                  0.478433    0.283867
# CA                  0.492603    0.318644
# CO                  0.481016         NaN
# CT                  0.490006    0.325751
# DE                  0.492833    0.323444
# FL                  0.469821    0.242444
# GA                  0.493560    0.196938
# HI                  0.499125    0.247250
# IA                  0.250003    0.090856
# ID                  0.494852    0.240648
# IL                  0.490136    0.242121
# IN                  0.500000    0.324326
# KS                  0.500000    0.247250
# KY                  0.454579    0.245298
# LA                  0.452469    0.241039
# MA                  0.330797    0.193610
# MD                  0.467729    0.320917
# ME                  0.419019         NaN
# MI                  0.487898    0.237316
# MO                  0.489509    0.243270
# MS                  0.493610    0.243381
# MT                  0.469205    0.300048
# NC                  0.462345    0.242882
# ND                  0.450415         NaN
# NE                  0.489258    0.304194
# NH                  0.500000    0.125000
# NJ                  0.500000    0.333333
# NM                  0.500015    0.304091
# NV                  0.498559    0.199047
# NY                  0.500000    0.333317
# OH                  0.492199    0.245074
# OK                  0.442182    0.196790
# OR                  0.500000    0.333352
# PA                  0.492522    0.325527
# RI                  0.491024    0.328683
# SC                  0.496587    0.166649
# SD                  0.500000    0.333394
# TN                  0.486184    0.195865
# TX                  0.479587    0.191356
# UT                  0.438103    0.333379
# VA                  0.496838    0.197638
# VT                  0.498407    0.191951
# WA                  0.498692    0.319778
# WI                  0.497597    0.323593
# WV                  0.431200    0.310333
# WY                  0.500000    0.235333

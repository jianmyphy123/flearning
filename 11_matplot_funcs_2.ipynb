# %%
# %matplotlib nbagg
import matplotlib
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
ax4 = fig.add_subplot(2,2,4)

# %%
import numpy as np
import pandas as pd

# %%
plt.plot(np.random.rand(50).cumsum())

# %%
ax1.hist(np.random.randn(100), bins=20)
# Out:
# (array([  4.,   3.,   6.,   6.,  11.,   5.,   8.,   7.,   8.,   3.,   8.,
#           8.,   5.,   5.,   4.,   2.,   2.,   1.,   1.,   3.]),
#  array([-1.97176496, -1.75107016, -1.53037537, -1.30968058, -1.08898578,
#         -0.86829099, -0.6475962 , -0.4269014 , -0.20620661,  0.01448819,
#          0.23518298,  0.45587777,  0.67657257,  0.89726736,  1.11796215,
#          1.33865695,  1.55935174,  1.78004653,  2.00074133,  2.22143612,
#          2.44213092]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2, 3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x106028390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109fd0dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10affe3c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10b036668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b06e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b09a978>]], dtype=object)

# %%
axes[1,2].plot(np.random.randn(50))

# %%
plt.plot(np.random.randn(30), color='g', marker='o', linestyle='--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(np.random.randn(30), 'k.-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fit, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.DataFrame(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)

# %%
data.plot(kind='barh', ax=axes[1], color='g', alpha=0.3)

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
ax.set_xticks([0, 250, 500, 750, 1000])
# Out:
# [<matplotlib.axis.XTick at 0x1122f3ac8>,
#  <matplotlib.axis.XTick at 0x1118cc6a0>,
#  <matplotlib.axis.XTick at 0x1118c2320>,
#  <matplotlib.axis.XTick at 0x112d187b8>,
#  <matplotlib.axis.XTick at 0x112d18e10>]

# %%
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                           rotation=30, fontsize='small')

# %%
ax.set_title('Random walk plot')
# Out:
# Text(0.5,1,'Random walk plot')

# %%
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
# Out:
# Text(70.8194,0.5,'Values')

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'b--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')

# %%
ax.legend(loc='best')

# %%
ax.get_xlim()
# Out:
# (-49.950000000000003, 1048.95)

# %%
ax.get_ylim()
# Out:
# (-75.572482893831889, 47.615548819700784)

# %%
ax.set_xlim([100, 900])
# Out:
# (100, 900)

# %%
ax.set_ylim([-100, 100])
# Out:
# (-100, 100)

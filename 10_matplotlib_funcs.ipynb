# %%
# %matplotlib nbagg

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s
# Out:
# 0    -0.873536
# 10    0.268839
# 20    0.545333
# 30    2.574412
# 40    2.578437
# 50    3.196022
# 60    4.525320
# 70    5.502132
# 80    5.852143
# 90    5.844487
# dtype: float64

# %%
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="756">

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0), 
                 columns=['A', 'B', 'C', 'D'], index=np.arange(0, 100, 10))

# %%
df
# Out:
#            A         B         C         D
# 0  -0.783527 -0.794341  0.739831  0.559671
# 10 -2.136653 -0.156140 -0.667482  2.102646
# 20 -4.114419 -0.290200  0.013933  1.371672
# 30 -3.944610  0.990242  0.258070  0.839519
# 40 -2.384248  1.267469  1.646146  0.502376
# 50 -2.929196  1.152246  2.549186 -0.769085
# 60 -3.052899  0.561699  0.096748  1.286480
# 70 -4.051820  1.110390 -1.055102  1.384589
# 80 -4.303348  1.996386 -0.743361  0.847670
# 90 -3.533682  2.326462 -2.779276  0.130147

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['B'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s2 = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
s2
# Out:
# a    0.481962
# b    0.472927
# c    0.854732
# d    0.085200
# e    0.755857
# f    0.303020
# g    0.335227
# h    0.155875
# i    0.201756
# j    0.261743
# k    0.103631
# l    0.970718
# m    0.237614
# n    0.160015
# o    0.461681
# p    0.384677
# dtype: float64

# %%
s2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.DataFrame(np.random.rand(6,4), index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns = pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

# %%
df2
# Out:
# Genus         A         B         C         D
# one    0.669423  0.578058  0.477803  0.409866
# two    0.061196  0.966587  0.269659  0.323253
# three  0.080431  0.181039  0.054694  0.627889
# four   0.365686  0.053028  0.391408  0.760344
# five   0.607976  0.572769  0.633858  0.893481
# six    0.230415  0.632693  0.985141  0.041368

# %%
df2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
s3
# Out:
# 0      0.381657
# 1      1.913177
# 2     -0.434275
# 3     -1.226363
# 4     -1.132401
# 5     -1.792591
# 6      0.511741
# 7     -0.002338
# 8     -0.040309
# 9      0.549968
# 10     1.072379
# 11     0.411486
# 12    -0.144816
# 13     0.116825
# 14     1.030146
# 15    -1.417769
# 16    -1.009700
# 17    -0.789675
# 18     1.572795
# 19    -1.683269
# 20    -0.661969
# 21    -0.657449
# 22     1.688637
# 23    -1.233109
# 24    -0.434543
# 25    -0.024188
# 26     1.038757
# 27     1.820683
# 28     1.248681
# 29     2.062824
#          ...
# 170   -0.571165
# 171   -2.390729
# 172    1.473943
# 173   -0.687978
# 174   -0.330647
# 175   -3.055135
# 176    0.775453
# 177   -0.536062
# 178    0.259497
# 179    1.512496
# 180   -0.073889
# 181   -0.053345
# 182   -0.262381
# 183   -1.172783
# 184    0.575916
# 185   -2.794385
# 186    0.115587
# 187   -0.310498
# 188    1.382226
# 189   -1.114785
# 190    0.753197
# 191   -0.541269
# 192    0.406185
# 193   -0.911506
# 194    0.343821
# 195    0.162290
# 196   -0.010058
# 197    0.533628
# 198    0.237934
# 199   -0.086478
# Length: 200, dtype: float64

# %%
s3.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3.hist(bins=100, normed=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis = 1)

# %%
X
# Out:
# array([[  2.17530282e+00,  -1.91812534e+00],
#        [  4.03723470e-01,  -7.60184308e+00],
#        [  1.27223058e+00,   2.89951799e+00],
#        [  3.08421208e-01,  -5.58705576e+00],
#        [  1.12725345e+00,  -6.76069792e+00],
#        [  1.94151982e+00,  -1.43415317e+00],
#        [  1.84745526e+00,  -4.10793384e+00],
#        [ -1.44228732e+00,  -2.37932323e+00],
#        [  7.24679045e-02,  -5.31565803e+00],
#        [  2.12887132e+00,  -4.53122039e+00],
#        [  3.61547671e-03,   1.56379871e+00],
#        [  1.42494253e+00,  -1.07905355e+00],
#        [  3.43541991e+00,   4.43351865e+00],
#        [  1.24200878e+00,  -2.65225553e+00],
#        [  2.73505963e+00,  -5.89896555e+00],
#        [  2.52226889e+00,  -8.54061563e+00],
#        [  1.73032126e+00,   1.08983977e+00],
#        [  1.91732653e+00,  -2.04397699e+00],
#        [  1.18807917e+00,  -4.23435520e-01],
#        [  3.20549582e+00,   2.07192157e-01],
#        [ -4.57709015e-01,  -3.28550250e+00],
#        [  7.73345397e-02,  -1.06495950e+00],
#        [  8.61287176e-01,  -1.99255548e+00],
#        [  5.59817854e-01,   2.48178480e+00],
#        [  1.99642943e+00,  -5.04828799e+00],
#        [  1.84234923e-01,   1.71298540e-01],
#        [  8.12908061e-01,   1.53780450e+00],
#        [  1.88604358e+00,  -2.60061555e+00],
#        [  2.04341752e-01,  -6.67359338e+00],
#        [ -4.48023610e-02,  -2.84559091e+00],
#        [  1.26262013e+00,  -7.68168640e+00],
#        [  1.92003553e+00,  -3.88843443e+00],
#        [  1.36011307e+00,  -1.43221524e+00],
#        [  1.93410864e+00,  -2.27944095e+00],
#        [ -4.37747969e-01,  -7.22724884e+00],
#        [ -9.25001287e-01,  -2.61946267e+00],
#        [  1.71021317e+00,   2.14423329e+00],
#        [  2.06506323e+00,  -9.44882363e+00],
#        [  1.12206838e+00,  -2.31789161e+00],
#        [  5.40517828e-01,   3.58624455e-01],
#        [ -8.41626563e-01,  -5.66702702e+00],
#        [  1.88506496e-01,  -6.71098544e+00],
#        [  6.90880791e-01,   9.02370842e-03],
#        [  1.64826586e+00,  -4.31737146e-01],
#        [  2.20460283e+00,  -8.79146044e+00],
#        [ -8.92594402e-02,  -7.16989234e+00],
#        [  2.61429284e-01,  -4.83550625e+00],
#        [  1.19240697e+00,  -1.38197788e+00],
#        [  1.74229080e+00,  -5.39108652e+00],
#        [ -1.27907177e+00,  -1.33231679e+00],
#        [  1.08903726e+00,   7.79892514e-02],
#        [  1.34633311e+00,  -5.79146435e-01],
#        [  1.37280613e+00,  -5.64086477e+00],
#        [  5.74366276e-01,  -7.83733673e+00],
#        [  2.83429490e+00,  -3.29742711e+00],
#        [  7.18502682e-01,   4.14610866e+00],
#        [  3.29642101e+00,  -6.51850231e+00],
#        [  2.46801564e+00,  -1.42481088e+00],
#        [  1.12864012e+00,  -5.29319707e+00],
#        [  1.41901855e+00,  -5.25120816e+00],
#        [  1.83177045e+00,  -4.74826346e+00],
#        [  2.12800616e+00,   2.28182722e+00],
#        [ -1.02386565e+00,  -6.03511643e+00],
#        [  1.69772339e+00,   1.46742430e+00],
#        [ -4.38833732e-01,   4.77271561e+00],
#        [ -5.53837088e-03,  -5.57443445e+00],
#        [  2.79937117e+00,  -2.82637101e+00],
#        [  3.84359329e-01,  -3.77556747e-01],
#        [  1.02816679e+00,   6.88588372e-01],
#        [  1.03731508e+00,  -3.19088328e+00],
#        [  9.24251461e-01,  -5.94685798e+00],
#        [  1.02554514e+00,  -6.07997391e+00],
#        [ -1.19217545e-01,  -2.21874349e+00],
#        [  1.37664832e+00,   1.46813685e+00],
#        [  5.77218020e-01,  -1.01494762e+01],
#        [  2.06645999e+00,  -2.80771222e+00],
#        [  1.66422681e+00,  -2.49425162e-01],
#        [  1.85372338e+00,  -7.63999563e+00],
#        [  5.09215634e-01,  -4.37745329e+00],
#        [ -7.78294216e-01,  -2.77852830e+00],
#        [  9.67750055e-01,  -3.24276087e+00],
#        [ -7.76266964e-01,  -3.01335710e-01],
#        [  2.76602683e-01,  -4.85665630e+00],
#        [  3.10646475e+00,   2.22318973e+00],
#        [  5.58433942e-02,  -7.98117318e+00],
#        [  1.01634357e+00,   5.88177125e+00],
#        [  2.71281010e-02,  -1.88141971e+00],
#        [  1.35259835e+00,  -1.38878981e+01],
#        [  2.06325817e+00,  -7.35796188e+00],
#        [  1.44297471e+00,  -8.04909418e+00],
#        [  4.63043804e-02,  -5.22150732e+00],
#        [  1.74776315e+00,  -3.57658458e+00],
#        [  1.77807635e+00,  -1.30020444e+00],
#        [  3.71674497e-01,   2.77703440e+00],
#        [  1.33691074e+00,  -3.28839243e+00],
#        [  8.74017193e-01,   3.65145349e+00],
#        [  1.62158080e+00,   7.98551639e+00],
#        [  9.12095152e-01,  -1.10216486e+01],
#        [  4.92791081e-02,  -4.38632046e+00],
#        [ -6.79059760e-01,  -1.05173610e+01]])

# %%
df3 = pd.DataFrame(X, columns=['x1', 'x2'])

# %%
df3
# Out:
#           x1         x2
# 0   2.175303  -1.918125
# 1   0.403723  -7.601843
# 2   1.272231   2.899518
# 3   0.308421  -5.587056
# 4   1.127253  -6.760698
# 5   1.941520  -1.434153
# 6   1.847455  -4.107934
# 7  -1.442287  -2.379323
# 8   0.072468  -5.315658
# 9   2.128871  -4.531220
# 10  0.003615   1.563799
# 11  1.424943  -1.079054
# 12  3.435420   4.433519
# 13  1.242009  -2.652256
# 14  2.735060  -5.898966
# 15  2.522269  -8.540616
# 16  1.730321   1.089840
# 17  1.917327  -2.043977
# 18  1.188079  -0.423436
# 19  3.205496   0.207192
# 20 -0.457709  -3.285503
# 21  0.077335  -1.064960
# 22  0.861287  -1.992555
# 23  0.559818   2.481785
# 24  1.996429  -5.048288
# 25  0.184235   0.171299
# 26  0.812908   1.537804
# 27  1.886044  -2.600616
# 28  0.204342  -6.673593
# 29 -0.044802  -2.845591
# ..       ...        ...
# 70  0.924251  -5.946858
# 71  1.025545  -6.079974
# 72 -0.119218  -2.218743
# 73  1.376648   1.468137
# 74  0.577218 -10.149476
# 75  2.066460  -2.807712
# 76  1.664227  -0.249425
# 77  1.853723  -7.639996
# 78  0.509216  -4.377453
# 79 -0.778294  -2.778528
# 80  0.967750  -3.242761
# 81 -0.776267  -0.301336
# 82  0.276603  -4.856656
# 83  3.106465   2.223190
# 84  0.055843  -7.981173
# 85  1.016344   5.881771
# 86  0.027128  -1.881420
# 87  1.352598 -13.887898
# 88  2.063258  -7.357962
# 89  1.442975  -8.049094
# 90  0.046304  -5.221507
# 91  1.747763  -3.576585
# 92  1.778076  -1.300204
# 93  0.371674   2.777034
# 94  1.336911  -3.288392
# 95  0.874017   3.651453
# 96  1.621581   7.985516
# 97  0.912095 -11.021649
# 98  0.049279  -4.386320
# 99 -0.679060 -10.517361
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2'])
# Out:
# <img src="data:image/png;base64,..." width="640">
